# %% [markdown]
# # Python: warm-up exercises on branching
#
# This notebook was generated in **solutions** mode.

# %% [markdown]
# ---
# ## Exercise 1: Check if Number is Even

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that checks whether a number `num` is even. If so, print a message.

# %% [markdown]
# #### Your solution

# %%
num = 42
if num % 2 == 0:
    print("Condition evaluates to True.")
    print("Number", num, "is even")

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 2: Even or Odd Message

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that checks whether a number `num` is even. Print a message about the outcome (odd or even).

# %% [markdown]
# #### Your solution

# %%
num = 42
if num % 2 == 0:
    print("Condition evaluates to True.")
    print("Number", num, "is even")
else:
    print("Condition evaluates to False.")
    print("Number", num, "is odd")

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 3: Conditional assignment

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that checks whether a number `num` is odd or even. Assign a proper value (e.g., 'odd' or 'even') to a variable `result`, depending on the outcome of the condition. Print the outcome at the end.

# %% [markdown]
# #### Your solution

# %%
num = 42
if num % 2 == 0:
    result = "even"
else:
    result = "odd"
print("Number", num, "is", result)

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 4: Multiple Divisibility Check

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that checks whether a number `num` is divisible by 2, 3, 5 and 7. Print a message when `num` is divisible by one of this number.

# %% [markdown]
# #### Your solution

# %%
num = 42
if num % 2 == 0:
    print("Number ", num, "is divisible by 2.")
if num % 3 == 0:
    print("Number ", num, "is divisible by 3.")
if num % 5 == 0:
    print("Number ", num, "is divisible by 5.")
if num % 7 == 0:
    print("Number ", num, "is divisible by 7.")

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 5: Nested Conditional Logic

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that checks whether a number `num` is odd or even. Print a message informing the user.
# If odd, check whether the number is divisible by 5. Print a message informing the user.
# If even, check whether the number is divisible by 3. Print a message informing the user.

# %% [markdown]
# #### Your solution

# %%
num = 15
if num % 2 == 0:
    print("Number", num, "is even.")
    if num % 3 == 0:
        print("Number", num, "is also divisible by 3.")
    else:
        print("Number", num, "is not divisible by 3.")
else:
    print("Number", num, "is odd.")
    if num % 5 == 0:
        print("Number", num, "is also divisible by 5.")
    else:
        print("Number", num, "is not divisible by 5.")

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))

# %% [markdown]
# ---
# ## Exercise 6: Dog Age Calculator

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a piece of code that asks the user to insert the dog's age in human's years and calculates a dog's age in dog's years. For the first two years, a dog year is equal to 10.5 human years. After that, each dog year equals 4 human years.

# %% [markdown]
# #### Your solution

# %%
age = int(input("Enter the dog's age in human years: "))
print("Inserted age:", age)

if age <= 2:
    dog_years = age * 10.5
else:
    dog_years = 2 * 10.5 + (age - 2) * 4

print("The dog's age in dog's years is:", dog_years)

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\n" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
