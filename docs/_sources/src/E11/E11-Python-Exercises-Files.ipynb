# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Files</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on files (no hints)](https://introcp.github.io/src/E11/E11-Python-Exercises-Files-student.html)
# - [Notebook with exercises on files (with pseudocode)](https://introcp.github.io/src/E11/E11-Python-Exercises-Files-pseudocode.html)
# - [Notebook with exercises on files (with solutions)](https://introcp.github.io/src/E11/E11-Python-Exercises-Files-solution.html)
