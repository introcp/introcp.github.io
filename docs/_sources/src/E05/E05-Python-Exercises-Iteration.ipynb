# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Iteration</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on iteration (no hints)](https://introcp.github.io/src/E05/E05-Python-Iteration-Exercises-student.html)
# - [Notebook with exercises on iteration (with pseudocode)](https://introcp.github.io/src/E05/E05-Python-Iteration-Exercises-pseudocode.html)
# - [Notebook with exercises on iteration (with solutions)](https://introcp.github.io/src/E05/E05-Python-Iteration-Exercises-solution.html)
