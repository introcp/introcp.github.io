# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Strings and Lists</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on strings and lists (no hints)](https://introcp.github.io/src/E06/E06-Python-Exercises-Strings-Lists-student.html)
# - [Notebook with exercises on strings and lists (with pseudocode)](https://introcp.github.io/src/E06/E06-Python-Exercises-Strings-Lists-pseudocode.html)
# - [Notebook with exercises on strings and lists (with solutions)](https://introcp.github.io/src/E06/E06-Python-Exercises-Strings-Lists-solution.html)
