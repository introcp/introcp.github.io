# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Dictionaries, Tuples and Sets</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on dictionaries, tuples, and sets (no hints)](https://introcp.github.io/src/E08/E08-Python-Exercises-Dicts-Tuples-Sets-student.html)
# - [Notebook with exercises on dictionaries, tuples, and sets (with pseudocode)](https://introcp.github.io/src/E08/E08-Python-Exercises-Dicts-Tuples-Sets-pseudocode.html)
# - [Notebook with exercises on dictionaries, tuples, and sets (with solutions)](https://introcp.github.io/src/E08/E08-Python-Exercises-Dicts-Tuples-Sets-solution.html)
