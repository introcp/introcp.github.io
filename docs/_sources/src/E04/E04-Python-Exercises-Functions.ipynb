# %% [markdown]
# # <b style="font-family: 'LUISS', 'Lato'">Exercises: Functions</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Introduction to computer programming</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Artificial Intelligence</h3>
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on functions (no hints)](https://introcp.github.io/src/E04/E04-Python-Exercises-Functions-student.html)
# - [Notebook with exercises on functions (with pseudocode)](https://introcp.github.io/src/E04/E04-Python-Exercises-Functions-pseudocode.html)
# - [Notebook with exercises on functions (with solutions)](https://introcp.github.io/src/E04/E04-Python-Exercises-Functions-solution.html)
