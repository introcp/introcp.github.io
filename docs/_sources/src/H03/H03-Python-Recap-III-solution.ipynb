# %% [markdown]
# # Python: Recap III
#
# This notebook was generated in **solutions** mode.

# %% [markdown]
# ---
# ## Exercise 1: Binary into decimal (recursive)

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(s)` that, given a string `s` composed by 0's and 1's representing a binary number, converts the binary number into base 10. You can assume the string to be non-empty.

# %% [markdown]
# #### Your solution

# %%
def my_function(s):
    if len(s) == 1:
        return int(s) * 2**0
    else:
        return int(s[0]) * 2**(len(s)-1) + my_function(s[1:])

# %% [markdown]
# #### Test your solution

# %%
assert my_function('1010') == 10
assert my_function('0') == 0
assert my_function('1') == 1
assert my_function('1111') == 15

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function('1010') == 10\nassert my_function('0') == 0\nassert my_function('1') == 1\nassert my_function('1111') == 15" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28s%29%3A%0A%20%20%20%20if%20len%28s%29%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20return%20int%28s%29%20%2A%202%2A%2A0%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20int%28s%5B0%5D%29%20%2A%202%2A%2A%28len%28s%29-1%29%20%2B%20my_function%28s%5B1%3A%5D%29%0A%0Aassert%20my_function%28%271010%27%29%20%3D%3D%2010%0Aassert%20my_function%28%270%27%29%20%3D%3D%200%0Aassert%20my_function%28%271%27%29%20%3D%3D%201%0Aassert%20my_function%28%271111%27%29%20%3D%3D%2015&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 2: Recursive decreasing of list elements

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(L, K)` that, given a list `L` of numbers and a number `K` strictly larger than `0`, returns a new list obtained by decreasing every element of `L` by `K`. If `L` is empty, the function should return an empty list.

# %% [markdown]
# #### Your solution

# %%
def my_function(L, K):
    if len(L) == 0:
        return []
    return [L[0] - K] + my_function(L[1:], K)

# %% [markdown]
# #### Test your solution

# %%
assert my_function([2, 12, 3, 7], 2) == [0, 10, 1, 5]
assert my_function([10, 10, 10, 9], 10) == [0, 0, 0, -1]
assert my_function([], 10) == []
assert my_function([1, 2, 3, 4, 5], 1) == [0, 1, 2, 3, 4]

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function([2, 12, 3, 7], 2) == [0, 10, 1, 5]\nassert my_function([10, 10, 10, 9], 10) == [0, 0, 0, -1]\nassert my_function([], 10) == []\nassert my_function([1, 2, 3, 4, 5], 1) == [0, 1, 2, 3, 4]" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28L%2C%20K%29%3A%0A%20%20%20%20if%20len%28L%29%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%20%5B%5D%0A%20%20%20%20return%20%5BL%5B0%5D%20-%20K%5D%20%2B%20my_function%28L%5B1%3A%5D%2C%20K%29%0A%0Aassert%20my_function%28%5B2%2C%2012%2C%203%2C%207%5D%2C%202%29%20%3D%3D%20%5B0%2C%2010%2C%201%2C%205%5D%0Aassert%20my_function%28%5B10%2C%2010%2C%2010%2C%209%5D%2C%2010%29%20%3D%3D%20%5B0%2C%200%2C%200%2C%20-1%5D%0Aassert%20my_function%28%5B%5D%2C%2010%29%20%3D%3D%20%5B%5D%0Aassert%20my_function%28%5B1%2C%202%2C%203%2C%204%2C%205%5D%2C%201%29%20%3D%3D%20%5B0%2C%201%2C%202%2C%203%2C%204%5D&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 3: Recursive find next element in list

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(L, V)` that, given a list `L` of strings and a string `V`, finds the first occurrence of `V` in `L` and returns the value of the next element in `L`. If `V` is not in `L` or is the last element, the function should return `0`.

# %% [markdown]
# #### Your solution

# %%
def my_function(L, V):
    if len(L) == 1:
        return 0
    if L[0] == V:
        return L[1]
    else:
        return my_function(L[1:], V)

# %% [markdown]
# #### Test your solution

# %%
assert my_function(['Luiss', 'is', 'the', 'best', 'Luiss', 'is', 'great'], 'is') == 'the'
assert my_function(['Luiss', 'is', 'is', 'best', 'Luiss', 'is', 'great'], 'is') == 'is'
assert my_function(['Luiss', 'best', 'Luiss', 'is'], 'is') == 0
assert my_function(['Luiss', 'best', 'Luiss', 'is'], 'aaaaaaa') == 0

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function(['Luiss', 'is', 'the', 'best', 'Luiss', 'is', 'great'], 'is') == 'the'\nassert my_function(['Luiss', 'is', 'is', 'best', 'Luiss', 'is', 'great'], 'is') == 'is'\nassert my_function(['Luiss', 'best', 'Luiss', 'is'], 'is') == 0\nassert my_function(['Luiss', 'best', 'Luiss', 'is'], 'aaaaaaa') == 0" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28L%2C%20V%29%3A%0A%20%20%20%20if%20len%28L%29%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20return%200%0A%20%20%20%20if%20L%5B0%5D%20%3D%3D%20V%3A%0A%20%20%20%20%20%20%20%20return%20L%5B1%5D%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20my_function%28L%5B1%3A%5D%2C%20V%29%0A%0Aassert%20my_function%28%5B%27Luiss%27%2C%20%27is%27%2C%20%27the%27%2C%20%27best%27%2C%20%27Luiss%27%2C%20%27is%27%2C%20%27great%27%5D%2C%20%27is%27%29%20%3D%3D%20%27the%27%0Aassert%20my_function%28%5B%27Luiss%27%2C%20%27is%27%2C%20%27is%27%2C%20%27best%27%2C%20%27Luiss%27%2C%20%27is%27%2C%20%27great%27%5D%2C%20%27is%27%29%20%3D%3D%20%27is%27%0Aassert%20my_function%28%5B%27Luiss%27%2C%20%27best%27%2C%20%27Luiss%27%2C%20%27is%27%5D%2C%20%27is%27%29%20%3D%3D%200%0Aassert%20my_function%28%5B%27Luiss%27%2C%20%27best%27%2C%20%27Luiss%27%2C%20%27is%27%5D%2C%20%27aaaaaaa%27%29%20%3D%3D%200&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 4: Harmonic sum of n (recursive)

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(n)` that calculates the harmonic sum of `n`. The harmonic sum is the sum of the reciprocals of the positive integers from 1 to `n` (both included). If `n` is not a positive integer, the function must return `-1`.

# %% [markdown]
# #### Your solution

# %%
def my_function(n):
    # exceptions
    if type(n) != int or n <= 0:
        return -1
    # base case
    if n == 1:
        return 1
    # recursive call
    return (1/n) + my_function(n-1)

# %% [markdown]
# #### Test your solution

# %%
assert abs(my_function(5) - 2.283333333333333) < 1e-12
assert abs(my_function(100) - 5.187377517639621) < 1e-12
assert my_function(-1) == -1
assert my_function(9.80645) == -1

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert abs(my_function(5) - 2.283333333333333) < 1e-12\nassert abs(my_function(100) - 5.187377517639621) < 1e-12\nassert my_function(-1) == -1\nassert my_function(9.80645) == -1" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28n%29%3A%0A%20%20%20%20%23%20exceptions%0A%20%20%20%20if%20type%28n%29%20%21%3D%20int%20or%20n%20%3C%3D%200%3A%0A%20%20%20%20%20%20%20%20return%20-1%0A%20%20%20%20%23%20base%20case%0A%20%20%20%20if%20n%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20return%201%0A%20%20%20%20%23%20recursive%20call%0A%20%20%20%20return%20%281/n%29%20%2B%20my_function%28n-1%29%0A%0Aassert%20abs%28my_function%285%29%20-%202.283333333333333%29%20%3C%201e-12%0Aassert%20abs%28my_function%28100%29%20-%205.187377517639621%29%20%3C%201e-12%0Aassert%20my_function%28-1%29%20%3D%3D%20-1%0Aassert%20my_function%289.80645%29%20%3D%3D%20-1&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 5: Recursive list multiplication by a factor

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(lst, v)` that takes a list of numbers `lst` and an integer number `v` as input, and returns the product of the list elements that are multiples of `v`. If there are no multiples of `v` in the list or the list is empty, the function should return `1`.

# %% [markdown]
# #### Your solution

# %%
def my_function(lst, v):
    if len(lst) == 0:
        return 1
    if lst[0] % v == 0:
        return lst[0] * my_function(lst[1:], v)
    return 1 * my_function(lst[1:], v)

# %% [markdown]
# #### Test your solution

# %%
assert my_function([5, 2, 10, 8, 9], 5) == 50
assert my_function([3, 2, 3, 7, 10], 3) == 9
assert my_function([2, 2, 2, 7, 10], 3) == 1
assert my_function([], 3) == 1

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function([5, 2, 10, 8, 9], 5) == 50\nassert my_function([3, 2, 3, 7, 10], 3) == 9\nassert my_function([2, 2, 2, 7, 10], 3) == 1\nassert my_function([], 3) == 1" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28lst%2C%20v%29%3A%0A%20%20%20%20if%20len%28lst%29%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%201%0A%20%20%20%20if%20lst%5B0%5D%20%25%20v%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%20lst%5B0%5D%20%2A%20my_function%28lst%5B1%3A%5D%2C%20v%29%0A%20%20%20%20return%201%20%2A%20my_function%28lst%5B1%3A%5D%2C%20v%29%0A%0Aassert%20my_function%28%5B5%2C%202%2C%2010%2C%208%2C%209%5D%2C%205%29%20%3D%3D%2050%0Aassert%20my_function%28%5B3%2C%202%2C%203%2C%207%2C%2010%5D%2C%203%29%20%3D%3D%209%0Aassert%20my_function%28%5B2%2C%202%2C%202%2C%207%2C%2010%5D%2C%203%29%20%3D%3D%201%0Aassert%20my_function%28%5B%5D%2C%203%29%20%3D%3D%201&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 6: Sum of local minima (recursive)

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Define a recursive function `my_function(L)` that takes as a parameter a list `L` and returns the sum of the values of the local minima in `L`. An element at position `i` in `L` is a local minimum if `L[i] < L[i-1]` and `L[i] < L[i+1]`. The first and the last elements in `L` cannot be local minima. If the input list is empty or there are no local minima, the function should return `0`.

# %% [markdown]
# #### Your solution

# %%
def my_function(l):
    if len(l) < 3:
        return 0
    if l[1] < l[0] and l[1] < l[2]:
        return l[1] + my_function(l[1:])
    else:
        return 0 + my_function(l[1:])

# %% [markdown]
# #### Test your solution

# %%
assert my_function([3, 4, 5, 1, 3, 2, 6]) == 3
assert my_function([1, 10, 11, 8, 10, 3]) == 8
assert my_function([1, 10, 11, 11, 10, 3]) == 0
assert my_function([]) == 0

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function([3, 4, 5, 1, 3, 2, 6]) == 3\nassert my_function([1, 10, 11, 8, 10, 3]) == 8\nassert my_function([1, 10, 11, 11, 10, 3]) == 0\nassert my_function([]) == 0" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28l%29%3A%0A%20%20%20%20if%20len%28l%29%20%3C%203%3A%0A%20%20%20%20%20%20%20%20return%200%0A%20%20%20%20if%20l%5B1%5D%20%3C%20l%5B0%5D%20and%20l%5B1%5D%20%3C%20l%5B2%5D%3A%0A%20%20%20%20%20%20%20%20return%20l%5B1%5D%20%2B%20my_function%28l%5B1%3A%5D%29%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%200%20%2B%20my_function%28l%5B1%3A%5D%29%0A%0Aassert%20my_function%28%5B3%2C%204%2C%205%2C%201%2C%203%2C%202%2C%206%5D%29%20%3D%3D%203%0Aassert%20my_function%28%5B1%2C%2010%2C%2011%2C%208%2C%2010%2C%203%5D%29%20%3D%3D%208%0Aassert%20my_function%28%5B1%2C%2010%2C%2011%2C%2011%2C%2010%2C%203%5D%29%20%3D%3D%200%0Aassert%20my_function%28%5B%5D%29%20%3D%3D%200&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 7: Sum of lengths of strings with lowercase vowels (recursive)

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(L)` that, given a list `L` of strings, returns the sum of the lengths of the strings in `L` containing at least one lowercase vowel. If the input list is empty or there are no strings containing at least one lowercase vowel, the function should return `0`.

# %% [markdown]
# #### Your solution

# %%
def vowelCheck(word):
    for letter in word:
        if letter in ['a', 'e', 'i', 'o', 'u']:
            return True
    return False

def my_function(L):
    if L == []:
        return 0
    else:
        thisString = L[0]
        if vowelCheck(thisString):
            return len(thisString) + my_function(L[1:])
        else:
            return 0 + my_function(L[1:])

# %% [markdown]
# #### Test your solution

# %%
assert my_function(['hello', 'try', 'IRENE', 'ccc', 'aaa']) == 8
assert my_function(['hEllO', 'try', 'IRENE', 'ccc']) == 0
assert my_function(['hEllO', 'try', 'IRENE', 'ccc', 'uuu', 'a']) == 4
assert my_function([]) == 0

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function(['hello', 'try', 'IRENE', 'ccc', 'aaa']) == 8\nassert my_function(['hEllO', 'try', 'IRENE', 'ccc']) == 0\nassert my_function(['hEllO', 'try', 'IRENE', 'ccc', 'uuu', 'a']) == 4\nassert my_function([]) == 0" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20vowelCheck%28word%29%3A%0A%20%20%20%20for%20letter%20in%20word%3A%0A%20%20%20%20%20%20%20%20if%20letter%20in%20%5B%27a%27%2C%20%27e%27%2C%20%27i%27%2C%20%27o%27%2C%20%27u%27%5D%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20True%0A%20%20%20%20return%20False%0A%0Adef%20my_function%28L%29%3A%0A%20%20%20%20if%20L%20%3D%3D%20%5B%5D%3A%0A%20%20%20%20%20%20%20%20return%200%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20thisString%20%3D%20L%5B0%5D%0A%20%20%20%20%20%20%20%20if%20vowelCheck%28thisString%29%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%20len%28thisString%29%20%2B%20my_function%28L%5B1%3A%5D%29%0A%20%20%20%20%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20return%200%20%2B%20my_function%28L%5B1%3A%5D%29%0A%0Aassert%20my_function%28%5B%27hello%27%2C%20%27try%27%2C%20%27IRENE%27%2C%20%27ccc%27%2C%20%27aaa%27%5D%29%20%3D%3D%208%0Aassert%20my_function%28%5B%27hEllO%27%2C%20%27try%27%2C%20%27IRENE%27%2C%20%27ccc%27%5D%29%20%3D%3D%200%0Aassert%20my_function%28%5B%27hEllO%27%2C%20%27try%27%2C%20%27IRENE%27%2C%20%27ccc%27%2C%20%27uuu%27%2C%20%27a%27%5D%29%20%3D%3D%204%0Aassert%20my_function%28%5B%5D%29%20%3D%3D%200&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 8: String with minimum length (recursive)

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(lst)` that takes a non-empty list of strings `lst` as input. The function shall return the element of `lst` having the minimum length. If there are several strings with the same minimum length, the function should return the string that appears first in the list. You can assume that there are no empty strings.

# %% [markdown]
# #### Your solution

# %%
def my_function(l):
    if len(l) == 1:
        return l[0]
    minstring = my_function(l[:-1])
    for el in l:
        if len(el) < len(minstring):
            minstring = el
    return minstring

# %% [markdown]
# #### Test your solution

# %%
assert my_function(['hello', 'how', 'are', 'you']) == 'how'
assert my_function(['a', 'how', 'aret', 'youh']) == 'a'
assert my_function(['hello', 'how', 'are', 'a']) == 'a'
assert my_function(['b', 't', 'c']) == 'b'

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function(['hello', 'how', 'are', 'you']) == 'how'\nassert my_function(['a', 'how', 'aret', 'youh']) == 'a'\nassert my_function(['hello', 'how', 'are', 'a']) == 'a'\nassert my_function(['b', 't', 'c']) == 'b'" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28l%29%3A%0A%20%20%20%20if%20len%28l%29%20%3D%3D%201%3A%0A%20%20%20%20%20%20%20%20return%20l%5B0%5D%0A%20%20%20%20minstring%20%3D%20my_function%28l%5B%3A-1%5D%29%0A%20%20%20%20for%20el%20in%20l%3A%0A%20%20%20%20%20%20%20%20if%20len%28el%29%20%3C%20len%28minstring%29%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20minstring%20%3D%20el%0A%20%20%20%20return%20minstring%0A%0Aassert%20my_function%28%5B%27hello%27%2C%20%27how%27%2C%20%27are%27%2C%20%27you%27%5D%29%20%3D%3D%20%27how%27%0Aassert%20my_function%28%5B%27a%27%2C%20%27how%27%2C%20%27aret%27%2C%20%27youh%27%5D%29%20%3D%3D%20%27a%27%0Aassert%20my_function%28%5B%27hello%27%2C%20%27how%27%2C%20%27are%27%2C%20%27a%27%5D%29%20%3D%3D%20%27a%27%0Aassert%20my_function%28%5B%27b%27%2C%20%27t%27%2C%20%27c%27%5D%29%20%3D%3D%20%27b%27&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>

# %% [markdown]
# ---
# ## Exercise 9: Recursive extraction of vowels from string

# %% [markdown]
# #### Exercise Description

# %% [markdown]
# Write a recursive function `my_function(S)` that, given a lower-case string `S`, returns the list containing all vowels in `S`. Each vowel should appear in the output list as many times and in the same order in which it appears in `S`. If the string is empty or there are no vowels in `S`, the function should return an empty list.

# %% [markdown]
# #### Your solution

# %%
def my_function(S):
    vowels = ['a', 'e', 'i', 'o', 'u']
    if len(S) == 0:
        return []
    if S[0] in vowels:
        return [S[0]] + my_function(S[1:])
    return [] + my_function(S[1:])

# %% [markdown]
# #### Test your solution

# %%
assert my_function('luiss learn is the best') == ['u', 'i', 'e', 'a', 'i', 'e', 'e']
assert my_function('aaeeoou') == ['a', 'a', 'e', 'e', 'o', 'o', 'u']
assert my_function('ccccddddpppzzzzz') == []
assert my_function('') == []

# %% [markdown]
# #### Debug your solution
#
# The following cells contain code to generate links to Python Tutor for debugging your code when running the tests. **You need to first run the cell containing your solution code before running the cell containing the Python Tutor link.**

# %%
from IPython.display import HTML;import urllib.parse as u;HTML('<a href="https://pythontutor.com/visualize.html#code={}&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>'.format(u.quote(next((x + "\n\nassert my_function('luiss learn is the best') == ['u', 'i', 'e', 'a', 'i', 'e', 'e']\nassert my_function('aaeeoou') == ['a', 'a', 'e', 'e', 'o', 'o', 'u']\nassert my_function('ccccddddpppzzzzz') == []\nassert my_function('') == []" for x in reversed(_ih) if x.strip() and all(k not in x for k in ["assert","print(","HTML(","display(","import","from IPython"]) and ("\n" in x or ("=" in x and len(x)>20))), (_ih[-2] if len(_ih)>1 else "# No code")))))
# Out:
# <a href="https://pythontutor.com/visualize.html#code=def%20my_function%28S%29%3A%0A%20%20%20%20vowels%20%3D%20%5B%27a%27%2C%20%27e%27%2C%20%27i%27%2C%20%27o%27%2C%20%27u%27%5D%0A%20%20%20%20if%20len%28S%29%20%3D%3D%200%3A%0A%20%20%20%20%20%20%20%20return%20%5B%5D%0A%20%20%20%20if%20S%5B0%5D%20in%20vowels%3A%0A%20%20%20%20%20%20%20%20return%20%5BS%5B0%5D%5D%20%2B%20my_function%28S%5B1%3A%5D%29%0A%20%20%20%20return%20%5B%5D%20%2B%20my_function%28S%5B1%3A%5D%29%0A%0Aassert%20my_function%28%27luiss%20learn%20is%20the%20best%27%29%20%3D%3D%20%5B%27u%27%2C%20%27i%27%2C%20%27e%27%2C%20%27a%27%2C%20%27i%27%2C%20%27e%27%2C%20%27e%27%5D%0Aassert%20my_function%28%27aaeeoou%27%29%20%3D%3D%20%5B%27a%27%2C%20%27a%27%2C%20%27e%27%2C%20%27e%27%2C%20%27o%27%2C%20%27o%27%2C%20%27u%27%5D%0Aassert%20my_function%28%27ccccddddpppzzzzz%27%29%20%3D%3D%20%5B%5D%0Aassert%20my_function%28%27%27%29%20%3D%3D%20%5B%5D&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&py=3&rawInputLstJSON=%5B%5D&textReferences=false" target="_blank" style="font-size:16px;color:blue;text-decoration:underline;">🔗 Visualize YOUR solution in Python Tutor</a>
