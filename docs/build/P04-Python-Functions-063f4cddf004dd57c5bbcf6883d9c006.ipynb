# %% [markdown]
# # Functions
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="../dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Reusing Code
#
# So far...
# - we have covered some basic language mechanisms
# - we know how to write:
#     - different `.py` files for different computations
#     - different code cells for different computations
# - ...where each file/cell contains some piece of code
# - ...and each code is a sequence of operations

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>PROBLEM</b>: This approach is:<br>
# <ul>
# <li>easy for small-scale problems</li>
# <li>messy for large-scale problems</li>
# <li>hard to keep track of details and maintain</li>
# <li>difficult to reuse within more complex programs</li>
# </ul>
# </div>

# %% [markdown]
# ## Functions
#
# More code does not necessarily mean good practice &rarr; use <b style="color:red">functions</b>.
#
# Why?

# %% [markdown]
# - functions are <b style="color:red">reusable</b> chunks of code
# - functions run if and only if are <i><b style="color:red">called</b></i> or <i><b style="color:red">invoked</b></i>

# %% [markdown]
# Characteristics of a function:
# - functions have a <b style="color:red">name</b>
# - functions have (0 or more) <b style="color:red">parameters</b>
# - functions have a <b style="color:red">docstring</b>*
# - functions have a <b style="color:red">body</b>
# - functions return <b style="color:red">something</b>.
#
# <small>*Optional, but recommended</small>

# %% [markdown]
# ### Anatomy of a function
# <div align="center">
#     <img src="img/Functions.png" style="width: 80%;">
# </div>

# %% [markdown]
# ### Function body
# <div align="center">
#     <img src="img/Functions2.png" style="width: 90%;">
# </div>

# %% [markdown]
# When a function is invoked, Python:
# - creates a <b style="color:red">frame</b> for the function call
# - <b style="color:red">assigns</b> arguments to parameters
# - <b style="color:red">executes</b> function body
# - <b style="color:red">erases</b> the frame
#
# Example:
# ```python
# def f(i):
#     j = i * 2
#     return j
#
# n = f(1)
# n = f(2)
# n = f(3)
# ```
#
# Let's see it in Python Tutor: [pythontutor.com](https://pythontutor.com/visualize.html#code=def%20f%28i%29%3A%0A%20%20%20%20j%20%3D%20i%20*%202%0A%20%20%20%20return%20j%0A%0An%3Df%281%29%0An%3Df%282%29%0An%3Df%283%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=311&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# ### The importance of `return`
# <div align="center">
#     <img src="img/Functions3.png" style="width: 70%;">
# </div>
#
# What happens when running e.g. `n=is_even(2)`?
#
# - Python returns `None` if no `return` is given
# - `None` represents the absence of a value

# %% [markdown]
# ### `print` vs. `return`
# <div style="display: flex; justify-content: space-around;">
#   <div>
#     <b><code>print</code></b>
#     <ul>
#       <li>can be placed <b style="color:red">anywhere</b></li>
#       <li>as <b style="color:red">many</b> <code>print</code> statements as you want</li>
#       <li>code <b style="color:red">after</b> <code>print</code> is executed</li>
#       <li>has a value <b style="color:red">outputted</b> to the console</li>
#     </ul>
#   </div>
#   <div>
#     <b><code>return</code></b>
#     <ul>
#       <li>has a meaning only <b style="color:red">inside</b> a function</li>
#       <li>only <b style="color:red">one</b> <code>return</code> statement is executed</li>
#       <li>code <b style="color:red">after</b> <code>return</code> is not executed</li>
#       <li>has a value <b style="color:red">returned</b> to the function caller</li>
#     </ul>
#   </div>
# </div>

# %% [markdown]
# ### One return, multiple values
# The `return` statement can return multiple values (if needed):
# - list of values separated by commas
# - returns a tuple*
#
# Example:

# %%
def hms(nsec):
    """Takes nsec (n. of seconds) and splits in hours, minutes, seconds"""
    hh = nsec // 3600
    nsec = nsec % 3600
    mm = nsec // 60
    ss = nsec % 60
    return hh, mm, ss

print(hms(4000))
print(hms(100000))
# Out:
# (1, 6, 40)
# (27, 46, 40)

# %% [markdown]
# <small>*We will see tuples later in the course, for now we just print multiple outputs.</small>

# %% [markdown]
# ## Variable Scope
# <div align="center">
#     <img src="img/Scope1.png" style="width: 100%;">
# </div>
#
# - the <b style="color:red">formal parameter</b> gets bound to the <b style="color:red">actual parameter</b> when the function is called
# - when entering a function, a new <b style="color:red">scope</b> (or <b style="color:red">frame</b>, or <b style="color:red">environment</b>) is created
# - the <b style="color:red">scope</b> is the mapping of names to objects

# %% [markdown]
# ### Running Example (1/4)
# <div align="center">
#     <img src="img/Example1.png" style="width: 90%;">
# </div>
#
# What's going on here?

# %% [markdown]
# 1. in the main (i.e., global) scope, we define function `f`
# 2. in the main scope, we define variable `x`
# 3. function `f` is called and variable `x` is fed to `f`

# %% [markdown]
# ### Running Example (2/4)
# <div align="center">
#     <img src="img/Example2.png" style="width: 100%;">
# </div>
#
# What's going on here?
# 1. variable `x` is changed inside `f` because of `x = x+1`

# %% [markdown]
# <div class="alert alert-block alert-info"><b>NOTE</b>: Variable <code>x</code> in the global scope has <b>not</b> been changed because <code>f</code> has its own scope!</div>

# %% [markdown]
# ### Running Example (3/4)
# <div align="center">
#     <img src="img/Example3.png" style="width: 100%;">
# </div>
#
# What's going on here?
# 1. variable `x` inside `f` is ready to be `return`ed
# 2. in the **global** scope, there is variable `z` ready to host the `return`ed value

# %% [markdown]
# ### Running Example (4/4)
# <div align="center">
#     <img src="img/Example4.png" style="width: 100%;">
# </div>
#
# What's going on here?
# 1. the frame of function `f` is destroyed because its execution is finished
# 2. in the **global** scope, we have the *original* value for `x`
# 3. in the **global** scope, we have the output of function `f` in the new variable `z`

# %% [markdown]
# ### Important Caveats on Variable Scopes (part 1)
#
# <div align="center">
#     <img src="img/Scope2.png" style="width: 100%;">
# </div>
#
# - inside a function, you <b style="color:red">can access</b> variables defined outside the function itself
# - inside a function, you <b style="color:red">cannot modify</b> variables defined outside the function itself
# - to modify variables defined outside, you must use the `global` keyword... which is frowned upon

# %% [markdown]
# ### Important Caveats on Variable Scopes (part 2)
#
# <div align="center">
#     <img src="img/Scope3.png" style="width: 100%;">
# </div>
#
# - due to the fact that (by default) you cannot modify variables inside a function, `x` remains untouched

# %% [markdown]
# ### The `global` Keyword
#
# - when we create a variable <b style="color:red">inside</b> a function, it is <b style="color:red">local</b> by default
# - when we create a variable <b style="color:red">outside</b> a function, it is <b style="color:red">global</b> by default
# - using the `global` keyword outside a function has no effect
# - we use the `global` keyword to <i>write</i>/<i>modify</i> a variable <b style="color:red">inside</b> a function

# %% [markdown]
# <br>
#
# For instance, let us consider this code:

# %%
def add():
    global c
    c = 3
    print("Inside add(): c = ", c)

c = 1
add()
print("In main(): c = ", c)
# Out:
# Inside add(): c =  3
# In main(): c =  3

# %% [markdown]
# Function `add` is modifying the global variable `c`.

# %% [markdown]
# <br>
#
# What happens if we omit the `global` keyword?

# %%
def add():
    c = 3 # this a local variable!
    print("Inside add(): c = ", c)

c = 1 # this is a global variable
add()
print("In main(): c = ", c)
# Out:
# Inside add(): c =  3
# In main(): c =  1

# %% [markdown]
# Function `add` is not modifying the global variable `c` but its own local variable.

# %% [markdown]
# ### Nested Functions
#
# - You can <b style="color:red">nest</b> functions arbitrarily.
# - Scopes of nested functions behave like Matryoshka dolls.

# %% [markdown]
# Let's see how thanks to [pythontutor.com](https://pythontutor.com/visualize.html#code=def%20g%28x%29%3A%0A%20%20%20%20def%20h%28%29%3A%0A%20%20%20%20%20%20%20%20x%20%3D%20'abc'%0A%20%20%20%20x%20%3D%20x%20%2B%201%0A%20%20%20%20print%28'g%3A%20x%20%3D',%20x%29%0A%20%20%20%20h%28%29%0A%20%20%20%20return%20x%0A%0Ax%20%3D%203%0Az%20%3D%20g%28x%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=311&rawInputLstJSON=%5B%5D&textReferences=false) on this example:

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('g: x =', x)
    h()
    return x

x = 3
z = g(x)
# Out:
# g: x = 4

# %% [markdown]
# ## Positional vs. Keyword Arguments
# We have seen <b style="color:red">positional bounding</b> of formal parameters to actual parameters:
# - the first formal parameter is bound to the first actual parameter
# - the second formal to the second actual
# - ...and so on, until all parameters are bounded

# %% [markdown]
# Python also supports <b style="color:red">keyword bounding</b>
# - formals are bound to actuals using the name of the formal parameter
#
# Example:

# %%
def add(a, b, c):
    return a + b + c

print(add(1, 2, 3))       # positional bounding a->1, b->2, c->3
print(add(c=3, a=1, b=2)) # keyword bounding (order does not matter)
# Out:
# 6
# 6

# %% [markdown]
# ### Optional and Default Parameters
# <b style="color:red">All</b> parameters need to be provided to a function:
# - via positional or keyword arguments
# - via default parameters
#
# <br>
#
# <br>
#
# For instance, when we consider this function:

# %%
def area_cylinder(radius=1, height=1):
    pi = 3.14
    bottom_area = pi * radius ** 2
    side_area = pi * height * radius * 2
    return side_area + bottom_area * 2

# %% [markdown]
# <br>
#
# When we call this function with **no parameters**:

# %%
def area_cylinder(radius=1, height=1):
    pi = 3.14
    bottom_area = pi * radius ** 2
    side_area = pi * height * radius * 2
    return side_area + bottom_area * 2

print("No parameters: ", area_cylinder())
# Out:
# No parameters:  12.56

# %% [markdown]
# The function will use the default values for the two parameters. Indeed:

# %%
print("Check: ", area_cylinder(1, 1))
# Out:
# Check:  12.56

# %% [markdown]
# <br>
#
# Or, we can call this function with **one parameter**:

# %%
def area_cylinder(radius=1, height=1):
    pi = 3.14
    bottom_area = pi * radius ** 2
    side_area = pi * height * radius * 2
    return side_area + bottom_area * 2

print("One parameter: ", area_cylinder(2))
# Out:
# One parameter:  37.68

# %% [markdown]
# We are passing only the first (positional) parameter. For the second one we are using the default value. Indeed:

# %%
print("Check: ", area_cylinder(2, 1))
# Out:
# Check:  37.68

# %% [markdown]
# <br>
#
# As already seen, the natural choice would be to call it with the **two parameters**:

# %%
def area_cylinder(radius=1, height=1):
    pi = 3.14
    bottom_area = pi * radius ** 2
    side_area = pi * height * radius * 2
    return side_area + bottom_area * 2

print("Two parameters: ", area_cylinder(2, 3))
# Out:
# Two parameters:  62.8

# %% [markdown]
# <br>
#
# If we want to set only one specific parameter (e.g., the second one), while keeping the default values for the other ones (e.g., the first parameter), then we can:

# %%
def area_cylinder(radius=1, height=1):
    pi = 3.14
    bottom_area = pi * radius ** 2
    side_area = pi * height * radius * 2
    return side_area + bottom_area * 2

print("Specific parameters: ", area_cylinder(height=2))
# Out:
# Specific parameters:  18.84

# %% [markdown]
# Which would be equivalent to:

# %%
print("Check: ", area_cylinder(1, 2))
# Out:
# Check:  18.84

# %% [markdown]
# ## Built-in Functions
# Python implements many functions by default, which are called <b style="color:red">built-in functions</b>.
#
# Examples of built-in functions:
# - numerical functions, such as `round(x)` and `pow(x,y)`*
# - casting, such as `int(x)`, `float(x)` and `str(x)`
# - input and output, namely `input()` and `print()`
# - help function, namely `help()`**
#
# Related functions are grouped into files, called <b style="color:red">modules</b>.
#
# <small>* Which is another way of doing exponentiation: `pow(x,y)` is the same as `x**y`.</small>
# <small>** The `help()` function takes as input the name of a function and returns its docstring.</small>

# %% [markdown]
# ## Modules
# <b style="color:red">Modular programming</b> is the way of breaking a large, unwieldy programming task into separate, smaller (and more manageable) subtasks.
#
# A <b style="color:red">module</b> is a piece of software with a specific functionality.
# For example, a game (e.g., chess, ping-pong, ...):
# - a module responsible for the game logic (rules)
# - a module responsible for graphics
#
# In Python, each module is a Python file with a `.py` extension, yet other extensions are also possible (e.g., pre-compiled C++).
#
# Modules contain some Python code (e.g., functions, class definitions, ...).

# %% [markdown]
# For instance, a `random` module might look like this:
#
# <div align="center">File: <code>random.py</code></div>

# %%
def sample(args):
    """Chooses k unique random elements from a population..."""
    # some code

def randint(args):
    """Return random integer in range [a, b], including both end points."""
    # some code

def random(args):
    """Get the next random number in the range [0.0, 1.0)."""
    # some code

# %% [markdown]
# ### Using Modules in Python
# Modules are <b style="color:red">imported</b> (in your script, in your function or in other modules) using the `import` command.
#
# You can use two different strategies for using a specific function from that module.
# 1. using the `<module>.<function>` notation

# %%
import random                 # or any other module
print(random.randint(1, 100)) # or any other function
# Out:
# 67

# %% [markdown]
# 2. using the `from` command

# %%
from random import randint # or any other function
print(randint(1, 100))
# Out:
# 75

# %% [markdown]
# <br>
#
# <div class="alert alert-block alert-warning"><b>WARNING</b>: Strategy #2 does not need the dot-notation (see Strategy #1). Yet, it only loads a specific function in your main!</div>

# %% [markdown]
# ### Common Modules in Python
# Python comes with many modules, including:
# - `io`: read and write from files
# - `math`: mathematical functions
# - `random`: pseudo-random number generator
# - `string`: useful string functions
# - `sys`: information about your operating system
#
# You can find the full list here:
# <div align="center"><a href="https://docs.python.org/3/library/">https://docs.python.org/3/library/</a></div>

# %% [markdown]
# An example: the `math` module:
# - Number-theoretic and representation functions
# - Power and logarithmic functions
# - Trigonometric functions
# - Angular conversion
# - Hyperbolic functions
# - Special functions and constants
#
# <br>
#
# <br>
#
# ```python
# >>> import math
# >>> print(math.factorial(x))      # return x!
# >>> print(math.log2(x))           # return the base-2 logarithm of x
# >>> print(math.cos(math.pi))      # return the cosine of pi
# >>> print(math.gcd(x,y))          # return the greatest common divisor
# ```
#
# <br>
# You can find the full list here:
# <div align="center"><a href="https://docs.python.org/3/library/math.html">https://docs.python.org/3/library/math.html</a></div>

# %% [markdown]
# ### Interactive Documentation
# You can browse the contents of a module interactively via the `dir()` function.

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# <br>
#
# <div class="alert alert-block alert-info"><b>NOTE</b>: Items beginning/ending with <code>__</code> are some metadata files. You can safely ignore them. For example, <code>__file__</code> contains the path pointing to the module source file.</div>

# %% [markdown]
# Given a list of functions, you can browse their documentation via the `help()` function.
#
# <br>
# <div class="alert alert-block alert-info"><b>RECALL</b>: The <code>help()</code> function takes as input the name of a function and returns its docstring.</div>
#
# <br>
#
# ```python
# >>> import math
# >>> help(math.log)
# Help on built-in function log in module math:
#
# log(...)
#     log(x, [base=math.e])
#     If the base not specified, returns the natural logarithm (base e) of x.
#
# (END)
# ```

# %% [markdown]
# ## Exercise Session on functions
#
# Find the exercises for the exercise session: [here](https://introcp.github.io/src/E04/E04-Python-Exercises-Functions.html)

# %% [markdown]
# ## Exercise Session on `math` and `datetime` modules
#
# Find the exercises for the exercise session: [here](https://introcp.github.io/src/E02/E02-Python-Exercises-Math-Datetime.html)
