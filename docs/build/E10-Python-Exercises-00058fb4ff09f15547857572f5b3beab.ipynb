# %% [markdown]
# # Exercises: Recursion
#
# ## Introduction to computer programming
# ### Management and Artificial Intelligence
# <br><img src="../dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on recursion (no hints)](E10-Python-Exercises-Recursion-student.ipynb)
# - [Notebook with exercises on recursion (with pseudocode)](E10-Python-Exercises-Recursion-pseudocode.ipynb)
# - [Notebook with exercises on recursion (with solutions)](E10-Python-Exercises-Recursion-solution.ipynb)
