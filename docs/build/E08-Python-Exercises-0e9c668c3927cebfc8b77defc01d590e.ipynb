# %% [markdown]
# # Exercises: Dictionaries, Tuples and Sets
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="../dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on dictionaries, tuples, and sets (no hints)](https://introcp.github.io/e08-python-exercises-dicts-tuples-sets-student)
# - [Notebook with exercises on dictionaries, tuples, and sets (with pseudocode)](https://introcp.github.io/e08-python-exercises-dicts-tuples-sets-pseudocode)
# - [Notebook with exercises on dictionaries, tuples, and sets (with solutions)](https://introcp.github.io/e08-python-exercises-dicts-tuples-sets-solution)
