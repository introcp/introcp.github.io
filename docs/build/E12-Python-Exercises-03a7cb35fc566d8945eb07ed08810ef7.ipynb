# %% [markdown]
# # Exercises: Loops with strings and lists
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="../dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on loops with strings and lists (no hints)](https://introcp.github.io/e12-python-exercises-loops-with-strings-lists-student)
# - [Notebook with exercises on loops with strings and lists (with pseudocode)](https://introcp.github.io/e12-python-exercises-loops-with-strings-lists-pseudocode)
# - [Notebook with exercises on loops with strings and lists (with solutions)](https://introcp.github.io/e12-python-exercises-loops-with-strings-lists-solution)
