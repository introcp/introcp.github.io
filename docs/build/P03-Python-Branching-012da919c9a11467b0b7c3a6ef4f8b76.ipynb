# %% [markdown]
# # Branching
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="../dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Branching
#
# <div style="display: flex; justify-content: space-around;">
#   <div style="text-align: center;">
#     <p>A program <b style="color:red">without branching</b></p>
#     <img src="img/Branching1.png" style="height: 400px;">
#   </div>
#   <div style="text-align: center;">
#     <p>A program <b style="color:red">with branching</b></p>
#     <img src="img/Branching2.png" style="height: 400px;">
#   </div>
# </div>

# %% [markdown]
# ## Branching in Python
#
# <div align="center">
#
# <div style="display: flex; column-gap: 50px; ">
#   <div style="width: 40px;"></div>
#   <div style="width: 200px;">
#     <b>Plain if</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     statement
#     ...</code></pre>
#   </div>
#   <div style="width: 200px;">
#     <b>if-else</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     ...
# else:
#     statement
#     ...</code></pre>
#   </div>
#   <div style="width: 200px;">
#     <b>if-elif-else</b>
#     <pre><code>if &lt;condition&gt;:
#     statement
#     ...
# elif &lt;condition&gt;:
#     statement
#     ...
# else:
#     statement
#     ...</code></pre>
#   </div>
# </div>
#
# </div>
#
# - `<condition>` yields `True` or `False`
# - Evaluate statements in that block if `<condition>` is `True`
# - Indentation is the key to delimit blocks
# - Place `:` at the end of `<condition>`

# %% [markdown]
# ## Examples: if

# %%
num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed. It's outside of the block.")
# Out:
# 3 is a positive number.
# This is always printed. It's outside of the block.

# %% [markdown]
# <br>

# %%
num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is always printed. It's outside of the block.")
# Out:
# This is always printed. It's outside of the block.

# %% [markdown]
# ## Flowchart of an `if` statement
#
# Logical flowchart of an if statement:
# <div align="center">
#     <img src="img/branching-if.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Examples: if-else

# %%
num = 1
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Number is positive or zero.

# %% [markdown]
# What happens with:
# - `num = 0`
# - `num = -5`
#
# ?

# %% [markdown]
# <br>

# %%
num = 0
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Number is positive or zero.

# %%
num = -5
if num >= 0:
    print("Number is positive or zero.")
else:
    print("Negative number.")
# Out:
# Negative number.

# %% [markdown]
# ## Flowchart of an `if-else` statement
#
# Logical flowchart of an if-else statement.:
# <div align="center">
#     <img src="img/branching-if-else.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Examples: if-elif-else

# %%
num = 3.4
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is positive.

# %% [markdown]
# What happens with:
# - `num = 0`
# - `num = -4.5`
#
# ?

# %% [markdown]
# <br>

# %%
num = 0
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is zero.

# %%
num = -4.5
if num > 0:
    print("Number is positive.")
elif num == 0:
    print("Number is zero.")
else:
    print("Number is negative.")
# Out:
# Number is negative.

# %% [markdown]
# ## Flowchart of an `if-elif-else` statement
#
# Logical flowchart of an if-elif-else statement:
# <div align="center">
#     <img src="img/branching-if-elif-else.png" style="height: 400px;">
# </div>

# %% [markdown]
# ## Nested Statements
#
# Branching statements `if`, `else` and `elif` can be nested arbitrarily.

# %%
num = 10
# or interactive:
# num = float(input()) # recall: input() returns a string
print("You entered: ", num)
if num >= 0:
    if num == 0:
        print("Number is zero")
    else:
        print("Number is positive")
else:
    print("Number is negative")
# Out:
# You entered:  10
# Number is positive

# %% [markdown]
# ## Indentation
#
# <div class="alert alert-block alert-info">
# <b>RECALL</b>: Indentation (tab or 4 spaces) delimits blocks of code in Python.
# </div>

# %%
x = 10.0 #float(input("Enter a value for x: "))
y = 20.0 #float(input("Enter a value for y: "))
print("x is", x)
print("y is", y)
if x == y:
    print("y and x are equal")
    if y != 0:
        print("Finally, x/y is", x / y)
elif x > y:
    print("y is smaller")
else:
    print("x is smaller")
# Out:
# x is 10.0
# y is 20.0
# x is smaller

# %% [markdown]
# ## Warm-up Exercises
#
# - [Notebook with exercises on branching (no hints)](https://introcp.github.io/p03-python-branching-exercises-student)
# - [Notebook with exercises on branching (with pseudocode)](https://introcp.github.io/p03-python-branching-exercises-pseudocode)
# - [Notebook with exercises on branching (with solutions)](https://introcp.github.io/p03-python-branching-exercises-solution)

# %% [markdown]
# ## Exercise Session
#
# Find more exercises [here](https://introcp.github.io/e03-python-exercises-branching).
