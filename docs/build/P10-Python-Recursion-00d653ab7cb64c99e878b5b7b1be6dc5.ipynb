# %% [markdown]
# # Recursion
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="../dist/img/logo2.png" width="200px">
#
#
# <br><br><br>

# %% [markdown]
# ## Preliminaries
#
# ***Recursion*** is a powerful programming technique where a function calls itself to **solve smaller instances of the same problem**. It's a fundamental concept in computer science and programming, enabling the creation of elegant and efficient solutions to complex problems.

# %% [markdown]
# To understand recursion properly, we need to first explore two fundamental data structures:
#
# 1. **Stacks**: Essential for tracking recursive function calls
#
# 2. **Queues**: Similar to Stacks, but with a different order of operations

# %% [markdown]
# ## Stacks
#
# The **stack** is one of the most popular abstract data types in computer science.

# %% [markdown]
# A stack is a sequence (collection) of elements where only the *last* element (i.e., the one at the *top* of the stack) can be accessed.

# %% [markdown]
# The allowed operations on a stack $\mathcal{S}$ are the following:
# - `push(`$e$`, `$\mathcal{S}$`)`: adds a new element $e \in V$, for any domain $V$, at the top of the stack $\mathcal{S}$
# - `pop(`$\mathcal{S}$`)`: returns and removes the current element at the top of the stack $\mathcal{S}$.

# %% [markdown]
# Optionally, it is possible to define an additional operation:
# - `peek(`$\mathcal{S}$`)`: reads the top element without modifying the stack.

# %% [markdown]
# A special domain value is $\mathcal{S}_\emptyset$, namely the empty stack.

# %% [markdown]
# As $\mathcal{S}_{\emptyset}$ has no elements:
# - `pop()` is not allowed
# - `peek()` is not allowed.

# %% [markdown]
# The stack is a **LIFO** (**L**ast-**I**n, **F**irst-**O**ut) data structure, because:
# - the last element that entered the stack (i.e., via `push()`)
# - ...is the one that will be removed first (i.e., via `pop()`)

# %% [markdown]
# Effect of <code>push()</code> and <code>pop()</code> over a stack:
#
# <div align="center">
#     <img src="img/Lifo_stack.png" width="80%">
# </div>

# %% [markdown]
# ### Simulating a Stack in Python
#
# You can simulate the behaviour of a stack with lists.

# %%
S = []          # start with an empty stack
S.insert(0, 1)  # step 1 in previous slide
S.insert(0, 2)  # step 2 in previous slide
S.insert(0, 3)  # step 3 in previous slide
S.insert(0, 4)  # step 4 in previous slide
S.insert(0, 5)  # step 5 in previous slide
S.insert(0, 6)  # step 6 in previous slide
print(S)
S.pop(0)        # step 7 in previous slide
S.pop(0)        # step 8 in previous slide
S.pop(0)        # step 9 in previous slide
S.pop(0)        # step 10 in previous slide
S.pop(0)        # step 11 in previous slide
print(S)
# Out:
# [6, 5, 4, 3, 2, 1]
# [1]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>RECALL</b>: <code>lst.insert(x, y)</code> inserts value <code>y</code> at position <code>x</code> in list <code>lst</code>.
# </div>

# %% [markdown]
# <br>
#
# <div class="alert alert-block alert-info">
# <b>NOTE</b>: Previously, we supposed that the head of the list is the top of the stack. You can also assume that the tail of the list is the head of the stack.
# </div>

# %%
S = []      # start with an empty stack
S.append(1) # step 1 in slide 4
S.append(2) # step 2 in slide 4
S.append(3) # step 3 in slide 4
S.append(4) # step 4 in slide 4
S.append(5) # step 5 in slide 4
S.append(6) # step 6 in slide 4
print(S)
S.pop()     # step 7 in slide 4
S.pop()     # step 8 in slide 4
S.pop()     # step 9 in slide 4
S.pop()     # step 10 in slide 4
S.pop()     # step 11 in slide 4
print(S)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1]

# %% [markdown]
# ## Queues
#
# The **queue** is another popular abstract data type in computer science.

# %% [markdown]
# A queue is a sequence (collection) of elements where only the "oldest" element can be accessed.

# %% [markdown]
# The allowed operations on a queue $\mathcal{Q}$ are the following:
# - `enqueue(`$e$`,`$\mathcal{Q}$`)`: adds a new element $e \in V$, for any domain $V$, at the beginning (back) of the queue $\mathcal{Q}$
# - `dequeue(`$\mathcal{Q}$`)`: returns and removes the current element at the end (front) of the queue $\mathcal{Q}$.

# %% [markdown]
# Optionally, it is possible to define an additional operation:
# - `peek(`$\mathcal{Q}$`)`: reads the last element without modifying the queue.

# %% [markdown]
# A special domain value is $\mathcal{Q}_\emptyset$, namely the empty queue.

# %% [markdown]
# As $\mathcal{Q}_\emptyset$ has no elements:
# - `dequeue()` is not allowed
# - `peek()` is not allowed.

# %% [markdown]
# The queue is a **FIFO** (**F**irst-**I**n, **F**irst-**O**ut) data structure, because:
# - the first element that entered the queue (i.e., via `enqueue()`)
# - ...is the one that will be removed first (i.e., via `dequeue()`)

# %% [markdown]
# Visual representation of a queue:
#
# <div align="center">
#     <img src="img/Data_Queue.svg.png" width="80%">
# </div>

# %% [markdown]
# ### Simulating a Queue in Python
#
# You can simulate the behaviour of a queue with lists.

# %%
Q = []          # start with an empty queue
Q.insert(0, 1)  # insert at the beginning = enqueue
Q.insert(0, 2)
Q.insert(0, 3)
Q.insert(0, 4)
Q.insert(0, 5)
Q.insert(0, 6)
print(Q)
Q.pop()         # pop at the end = dequeue
Q.pop()
Q.pop()
Q.pop()
Q.pop()
print(Q)
# Out:
# [6, 5, 4, 3, 2, 1]
# [6]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NOTE</b>: Here we suppose that the head of the list is the beginning (back) of the queue and that the tail of the list is the end (front) of the queue.
# </div>

# %% [markdown]
# ## Queue vs. Stack
#
# | Data Structure | Visual Representation |
# | -------- | :-------: |
# | Stack  | <img src="img/l8r4ic2gedi0j9obd7ix.jpg" width="100%">    |
# | Queue | <img src="img/fcxri84smzo9m1pxbxj9.png" width="100%">     |

# %% [markdown]
# Or, more informally:
#
# | Stack | Queue |
# | :--------: | :-------: |
# | <img src="img/Tallrik_-_Ystad-2018.jpg" width="70%">  | <img src="img/0_25203CE7-A5F0-48DF-8882-165CB0F63B2Fjpeg.jpg" width="150%">    |

# %% [markdown]
# ## Recursion
#
# <div align="center">
#     <img src="img/recursionimage.jpg" width="60%">
# </div>

# %% [markdown]
# ### Recursion and Problem Solving
#
# When designing the solution of a problem

# %% [markdown]
# <div align="center">
#     <span style="color:red">...try to solve the problem assuming that you have <i>already solved it</i>!</span>
# </div>

# %% [markdown]
# How is that possible?

# %% [markdown]
# <div align="center">
#     <span style="color:red">Define the solution of a problem instance in terms of the solution of <i>smaller</i> problem instances.</span>
# </div>

# %% [markdown]
# Practically speaking:
#
# <div align="center">
#     <span style="color:red">The function that computes the solution will <i>invoke itself</i> (once or more than once) from inside its body.</span>
# </div>

# %% [markdown]
# ### Real-world recursion
#
# <div align="center" style="display: flex; justify-content: center;">
#     <figure>
#         <img src="img/800px-Mandel_zoom_08_satellite_antenna.jpg" width="200px">
#         <figcaption>Mandelbrot Set</figcaption>
#     </figure>
#     <figure>
#         <img src="img/escher-fish.jpg" width="200px">
#         <figcaption>Escher's Circle Limit III</figcaption>
#     </figure>
# </div>
# <div align="center" style="display: flex; justify-content: center;">
#     <figure>
#         <img src="img/An-image-of-the-Koch-snowflake-a-fractal-with-fractal-dimension-d-126-From_W640.jpg" width="200px">
#         <figcaption>Koch Snowflake</figcaption>
#     </figure>
#     <figure>
#         <img src="img/Infinity_Mirror_Effect.jpg" width="200px">
#         <figcaption>Parallel Mirrors</figcaption>
#     </figure>
# </div>

# %% [markdown]
# A more practical example? Computing the factorial of a number $n$:
#
# $$ n! = n \cdot (n-1) \cdot (n-2) \cdot \ldots \cdot 1 $$

# %% [markdown]
# Back-of-the-envelope calculation: $5!$
#
# $$
# \begin{equation*}
# 	5! = \underbrace{5 \cdot \underbrace{4 \cdot \underbrace{3 \cdot \underbrace{2 \cdot \underbrace{1}_\text{$1!$}}_\text{$2 \cdot 1!$}}_\text{$3 \cdot 2!$}}_\text{$4 \cdot 3!$}}_\text{$5 \cdot 4!$}
# \end{equation*}
# $$

# %% [markdown]
# We can spot the following pattern:
#
# $$ n! = n \cdot (n-1)! $$
#
# with base case:
#
# $$ 0! = 1 $$

# %% [markdown]
# ### Recursion and Problem Solving (cont'd)
#
# In order to use a recursive approach:
# 1. you must be able to <span style="color:red"><b>decompose</b></span> the problem into problems of the same type
# 2. you must find a <span style="color:red"><b>relation</b></span> that connects a given problem to the solution of similar subproblems
# 3. you need to know the solution of a special case of the problem (the <span style="color:red"><b>base case</b></span>, where the recursion terminates).

# %% [markdown]
# Take the factorial example:
# 1. multiplication between two numbers
# 2. multiplication between $n$ and the already-known $(n-1)!$
# 3. the base case is $0!=1$

# %% [markdown]
# ### Approach for Problem Decomposition
#
# When solving a task with a recursive approach:

# %% [markdown]
# 1. **Identify the base case(s)**: Determine the simplest version of the problem that can be solved directly. For instance: we know that the factorial of 0 is 1, i.e. $0! = 1$

# %% [markdown]
# 2. **Define the recursive case**: Break down the problem into a smaller version of the same problem. For instance, the factorial of a number $n$ can be computed by computing $factorial(n-1)$.

# %% [markdown]
# 3. **Ensure progress toward the base case**: Make sure each recursive call moves closer to the base case. For instance, the recursive call in the factorial function moves closer to the base case by decreasing the value of n by 1 in each recursive call.

# %% [markdown]
# 4. **Combine the results**: Determine how to combine the result of the recursive call with any additional processing needed. For instance, in the factorial function, we need to multiply the result of the recursive call by the current value of `n`.

# %% [markdown]
# 5. **Verify correctness**: Test with simple examples to ensure your recursive solution works properly.

# %% [markdown]
# ### Issues with Recursion
#
# There are two major issues with recursion:

# %% [markdown]
# 1. <span style="color:red"><b>Infinite recursion</b></span>
#     - missing base case?
#     - function called with wrong arguments?
#     For example, what happens if we do `(-1)!`?
#     <br>...more on this later

# %% [markdown]
# 2. <span style="color:red"><b>Un-responsiveness</b></span>
#     - your code can easily become very slow, also with *easy* input parameters
#     - ... more on memory management later

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NOTE</b>: Python is quite good at catching infinite recursions: it has a dedicated error:
# <br>
# <span style="color:red"><b><code>RecursionError: maximum recursion depth exceeded in comparison</code></b></span>
# </div>

# %% [markdown]
# ### Keeping track of recursive calls
#
# To trace recursive function calls, we need to use a **stack** data structure:
# - Each time a recursive function is called, a new frame is pushed onto the call stack, containing the function's parameters and local variables.
# - When a function returns, its frame is popped off the stack.
#
# This stack-based mechanism allows the program to *remember* where to return after each recursive call completes.

# %% [markdown]
# ## Example: `countdown`
#
# Write a recursive function `countdown(n)` that takes a positive integer `n` and prints the countdown. As the countdown reaches 0, prints `Blastoff!` and quits.

# %% [markdown]
# 1. **Identify the base case(s)**: when $n=0$, print `Blastoff!`

# %% [markdown]
# 2. **Identify the recursive case(s)**: when $n>0$, print $n$ and call the function with $n-1$

# %% [markdown]
# 3. **Ensure progress toward the base case**: the recursive call is with $n-1$, which is smaller than $n$ and will eventually reach $0$, our base case.

# %%
def countdown(n):
    if n==0:
        print("Blastoff!")
    else:
        print(n)
        countdown(n-1)

countdown(3)
# Out:
# 3
# 2
# 1
# Blastoff!

# %% [markdown]
# What's going on here?
#
# - (1) The execution of `countdown` begins with `n=3`, and since `n` is greater than `0`, it outputs the value `3`, and then calls itself...
#     - (2) The execution of `countdown` begins with `n=2`, and since `n` is greater than `0`, it outputs the value `2`, and then calls itself...
#         - (3) The execution of `countdown` begins with `n=1`, and since `n` is greater than `0`, it outputs the value `1`, and then calls itself...
#             - (4) The execution of `countdown` begins with `n=0`, and since `n` is not greater than `0`, it outputs `Blastoff!` and then returns.
#         - (5) The countdown that got `n=1` returns.
#     - (6) The countdown that got `n=2` returns.
# - (7) The countdown that got `n=3` returns.
# And we are back into the `main` script.

# %% [markdown]
# <br>
#
# <div class="alert alert-block alert-info">
# <b>RECALL</b>: Every time a function gets called, Python creates a new function frame, which contains the function's local variables and parameters.
# </div>
#
# For a recursive function, there might be more than one frame at the same time. Python organises those frames as a <span style="color:red"><b>stack</b></span>.
#
# For instance, the stack diagram for <code>countdown(3)</code> is:
# <div align="center">
#     <img src="img/book007.png" width="30%">
# </div>

# %% [markdown]
# How does the stack in the figure works?
# 1. (as usual) at the top of the stack is the frame for the `main`*
# 2. we call `countdown(3)`, so there is a new frame in the stack
# 3. `countdown(3)` calls `countdown(2)`, so there is a new frame in the stack
# 4. `countdown(2)` calls `countdown(1)`, so there is a new frame in the stack
# 5. `countdown(1)` calls `countdown(0)`, so there is a new frame in the stack
# 6. `countdown(0)` does not make any further calls, so no more frames
#
# <small>* In our case, it is empty because we did not create any variables in main or pass any arguments to it.</small>

# %% [markdown]
# We did a bunch of `push`es, now we must do some `pop`s:
# 1. `countdown(0)` finishes its execution (i.e., prints `Blastoff!` without doing anything else). Its frame is erased.
# 2. the control goes back to `countdown(1)`, which finishes its execution. Its frame is erased.
# 3. the control goes back to `countdown(2)`, which finishes its execution. Its frame is erased.
# 4. the control goes back to `countdown(3)`, which finishes its execution. Its frame is erased.
# 5. the control goes back to the `main`.

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### `factorial`
#
# Write a recursive function `factorial(n)` that takes as input a positive integer `n` and returns $n!$

# %% [markdown]
# Computing the factorial of a number $n$:
#
# $$ n! = n \cdot (n-1) \cdot (n-2) \cdot \ldots \cdot 1 $$

# %% [markdown]
# Hence:

# %% [markdown]
# - **Base case**:
#     - When $n=0$, then $1$
#     - This comes from: $0! = 1$

# %% [markdown]
# - **Recursive case**:
#     - otherwise we know that the factorial of $n$ is $n$ times the factorial of $n-1$
#     - This comes from $n! = n \cdot (n-1)!$

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n * factorial(n-1)

output = factorial(5)
print(output)
# Out:
# 120

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>WARNING</b>: What happens when calling <code>factorial(-1)</code>?
# </div>

# %% [markdown]
# Stack diagram for `factorial(3)`:
#
# <div align="center">
#     <img src="img/stackframes_factorial.png" width="50%">
# </div>

# %% [markdown]
# ### `palindrome`
#
# Write a recursive function `palindrome(s)` that takes as input a string `s` and returns `True` if `s` is palindrome and `False` otherwise.

# %% [markdown]
# Decomposition strategy: let `s` be `"racecar"`
# - <span style="color:red">r</span>aceca<span style="color:red">r</span> -> same letter ✓
# - <span style="color:blue">a</span>cec<span style="color:blue">a</span> -> same letter ✓
# - <span style="color:magenta">c</span>e<span style="color:magenta">c</span> -> same letter ✓
# - e -> trivial ✓

# %% [markdown]
# and now let `s` be `"rediviuer"`
# - <span style="color:red">r</span>ediviue<span style="color:red">r</span> -> same letter ✓
# - <span style="color:blue">e</span>diviu<span style="color:blue">e</span> -> same letter ✓
# - <span style="color:magenta">d</span>ivi<span style="color:magenta">u</span> -> different letter ✗
#
# Hence, `"racecar"` is palindrome, but `"rediviuer"` it's not.

# %% [markdown]
# From what we have seen so far:

# %% [markdown]
# - **Base case**:
#     - when the string is empty or 1 character long, it is a palindrome

# %% [markdown]
# - **Recursive case**:
#     - otherwise, check if the first and last characters are the same
#     - if they are, remove the first and last characters and recursively check the remaining string
#     - if they are not, it is not a palindrome

# %%
def palindrome(s):
    if len(s) <= 1:
        return True
    else:
        return (s[0] == s[-1]) and palindrome(s[1:-1])

output1 = palindrome("racecar")
print(output1)
output2 = palindrome("rediviuer")
print(output2)
# Out:
# True
# False

# %% [markdown]
# Stack diagram for `palindrome("racecar")`:
#
# <div align="center">
#     <img src="img/stackframes_palindrome.png" width="80%">
# </div>

# %% [markdown]
# Stack diagram for `palindrome("rediviuer")`:
#
# <div align="center">
#     <img src="img/stackframes_palindrome2.png" width="85%">
# </div>

# %% [markdown]
# ### `fibonacci`
#
# Write a recursive function `fibonacci(n)` that takes as input a positive integer `n` and returns the $n$-th Fibonacci number.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>RECALL</b>: Each number in the Fibonacci sequence is given by the sum of the two preceding ones:
#
# $$ F(n) = F(n-1) + F(n-2) $$
#
# where $F(0) = 0$ and $F(1) = 1$.
#
# Hence: 0 1 <span style="color:blue">1 2 3 5 8 13 ...</span>
# </div>

# %% [markdown]
# Decomposition strategy: `fibonacci(n)` with `n=5`*:
#
# $$
# \begin{equation*}
# 	\underbrace{5}_{\textstyle \underbrace{3}_{\textstyle\underbrace{2}_{\textstyle 1+1}+1} + \underbrace{2}_{\textstyle 1+1}}
# \end{equation*}
# $$
#
# <small>* By coincidence, the 5th Fibonacci number is 5.</small>

# %% [markdown]
# From what we have seen so far:

# %% [markdown]
# - **Base case**:
#     - When $n=0$, then $f(0) = 0$
#     - When $n=1$, then $f(1) = 1$

# %% [markdown]
# - **Recursive case**:
#     - Otherwise the fibonacci number is the sum of the previous two numbers, i.e., $f(n) = f(n-1) + f(n-2)$

# %%
def fibonacci(n):
    if n in [0, 1]:
        return n
    else:
        return (fibonacci(n-1) + fibonacci(n-2))

output = fibonacci(5)
print(output)
# Out:
# 5

# %% [markdown]
# Call Stack diagram for `fibonacci(5)`:
# <div align="center">
#     <img src="img/stackframes_fibonacci.png" width="100%">
# </div>

# %% [markdown]
# Return Stack diagram for `fibonacci(5)`:
#
# <div align="center">
#     <img src="img/stackframes_fibonacci2.png" width="100%">
# </div>

# %% [markdown]
# ## Exercise session
#
# Find the exercises for the exam session: [here](../E10/E10-Python-Exercises-Recursion.ipynb)
