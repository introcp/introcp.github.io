# %% [markdown]
# # Exercises: Strings and Lists
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on strings and lists (no hints)](https://introcp.github.io/e06-python-exercises-strings-lists-student)
# - [Notebook with exercises on strings and lists (with pseudocode)](https://introcp.github.io/e06-python-exercises-strings-lists-pseudocode)
# - [Notebook with exercises on strings and lists (with solutions)](https://introcp.github.io/e06-python-exercises-strings-lists-solution)
