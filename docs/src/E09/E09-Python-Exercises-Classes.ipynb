# %% [markdown]
# # Exercises: Classes
#
# ## Introduction to computer programming
# ### Management and Artificial Intelligence
# <br><img src="https://introcp.github.io/dist/img/logo2.png" width="200px"><br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on classes (no hints)](E09-Python-Exercises-Classes-student.ipynb)
# - [Notebook with exercises on classes (with pseudocode)](E09-Python-Exercises-Classes-pseudocode.ipynb)
# - [Notebook with exercises on classes (with solutions)](E09-Python-Exercises-Classes-solution.ipynb)
