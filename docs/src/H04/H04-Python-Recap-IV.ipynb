# %% [markdown]
# # Homework Exercises on Python (part IV)
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on Python (no hints)](H04-Python-Recap-IV-student.ipynb)
# - [Notebook with exercises on Python (with pseudocode)](H04-Python-Recap-IV-pseudocode.ipynb)
# - [Notebook with exercises on Python (with solutions)](H04-Python-Recap-IV-solution.ipynb)
