# %% [markdown]
# # Exercises: Functions
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on functions (no hints)](https://introcp.github.io/e04-python-exercises-functions-student)
# - [Notebook with exercises on functions (with pseudocode)](https://introcp.github.io/e04-python-exercises-functions-pseudocode)
# - [Notebook with exercises on functions (with solutions)](https://introcp.github.io/e04-python-exercises-functions-solution)
