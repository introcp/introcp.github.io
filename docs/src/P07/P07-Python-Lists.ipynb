# %% [markdown]
# # Lists
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## A List is a Sequence of Items
#
# In Python, lists:
# - are ordered <font color='red'><b>sequences</b></font> of items that can be accessed via index (remember: Python is 0-based!)
# - are denoted by <font color='red'><b>square brackets</b></font>, i.e. `[]`

# %% [markdown]
# A list contains <font color='red'><b>elements</b></font>, that can either be:
# - *homogeneous* (e.g., all integers, all strings, ...)
# - *heterogeneous* (less common)

# %% [markdown]
# Conversely to strings, lists are <font color='red'><b>mutable</b></font>:
# - elements can be changed

# %% [markdown]
# ### Indices and Ordering

# %%
a_list = []                     # an empty list
L = [2, 'a', 4, [1, 2]]         # an heterogeneous list

print(f'len(L) = {len(L)}')
print(f'L[0] = {L[0]}')
print(f'L[2] + 1 = {L[2] + 1}')
print(f'L[3] = {L[3]}')         # another list
# Out:
# len(L) = 4
# L[0] = 2
# L[2] + 1 = 5
# L[3] = [1, 2]

# %% [markdown]
# <div class="alert alert-block alert-info"><b>NOTE</b>: List elements are indexed from <code>0</code> to <code>len(L)-1</code>.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>HINT</b>: Use <code>range(len(L))</code> to get the valid indices of a list <code>L</code>.</div>

# %%
print(L[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(L[4])
#
# IndexError: list index out of range

# %% [markdown]
# <br>

# %%
i = 2
print(f'L[i-1] = {L[i-1]}')
# Out:
# L[i-1] = a

# %%
print(f'L[1:3] = {L[1:3]}')
# Out:
# L[1:3] = ['a', 4]

# %% [markdown]
# ## Mutability
#
# <div class="alert alert-block alert-info"><b>NOTE</b>: Lists are <font color='red'><b>mutable</b></font>.</div>
#
# The assignment of an element at a given index changes the value!

# %%
L = [2, 1, 3]
print(f'Original L: {L}')
L[1] = 5
print(f'Modified L: {L}')
# Out:
# Original L: [2, 1, 3]
# Modified L: [2, 5, 3]

# %% [markdown]
# <div class="alert alert-block alert-info"><b>NOTE</b>: This is the <font color='red'><b>same object</b></font> <code>L</code>.</div>
#
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/cloud.png" style="height: 150px;">
# </div>

# %% [markdown]
# ## Iterating
#
# Common strategies:
#
# 1. Iterate over the elements of the list:
#     - Simpler: no need to mess with indices
#     - We can only read the elements but we cannot update them
#
# 2. Iterate over the indices of the list:
#     - Slightly harder: we need to use the indices
#     - We can both read and update the elements.

# %% [markdown]
# ### Example: compute the sum of elements of a list

# %% [markdown]
# Approach #1: Iterate by element

# %%
L = [2, 5, 3]
total = 0
for e in L:         # Extract each element of the list
    total += e
print(f'Sum: {total}')
# Out:
# Sum: 10

# %% [markdown]
# Approach #2: Iterate by index

# %%
L = [2, 5, 3]
total = 0
for i in range(len(L)): # Using range(len(L)) to get valid indexes
    total += L[i]       # extract element at index i
print(f'Sum: {total}')
# Out:
# Sum: 10

# %% [markdown]
# ### Updating elements while iterating
#
# Suppose we want to increment by 1 each element of a list while iterating over it.

# %% [markdown]
# Approach #2: Iterate by index

# %%
L = [2, 5, 3]
for i in range(len(L)): # Using range(len(L)) to get valid indexes
    L[i] += 1           # we update the original element through indexing
print(f'L: {L}')        # OK: the list has been updated
# Out:
# L: [3, 6, 4]

# %% [markdown]
# Approach #1: Iterate by element

# %%
L = [2, 5, 3]
for e in L:         # Extract each element of the list
    e += 1          # We only get a copy of the element
print(f'L: {L}')    # KO: the list was NOT updated!
# Out:
# L: [2, 5, 3]

# %% [markdown]
# ## Basic Operations

# %% [markdown]
# ### `append()`
#
# <font color='red'><b>Add</b></font> elements to the end of a list `L` with:<br>
#
# ```python
# L.append(<elements>)
# ```
#
# <br>

# %%
L = [2, 1, 3]
print(f'Original L: {L}')
L.append(5) # lists are objects with data, methods and functions
print(f'L after append: {L}')
# Out:
# Original L: [2, 1, 3]
# L after append: [2, 1, 3, 5]

# %% [markdown]
# <div class="alert alert-block alert-info"><b>NOTE</b>: <code>append()</code> mutates the list!</div>
#
# <div class="alert alert-block alert-info"><b>NOTE</b>: Like methods in strings, methods in lists also use the dot notation.</div>

# %% [markdown]
# ### `+` vs. `extend()`
#
# <font color='red'><b>Concatenate</b></font> lists `L1` and `L2` together with:
#
# ```python
# L1.extend(L2)
# ```
#
# or:
#
# ```python
# L1 + L2
# ```
#
# <br>

# %%
L1 = [2, 1, 3]
L2 = [4, 5, 6]
L3 = L1 + L2
print(f'L1: {L1}')
print(f'L2: {L2}')
print(f'L3 = L1 + L2: {L3}')

L1.extend(L2)
print(f'L1 after extend: {L1}')
# Out:
# L1: [2, 1, 3]
# L2: [4, 5, 6]
# L3 = L1 + L2: [2, 1, 3, 4, 5, 6]
# L1 after extend: [2, 1, 3, 4, 5, 6]

# %% [markdown]
# ### Similar but different...
#
# <div class="alert alert-block alert-info"><b>NOTE</b>: <code>extend()</code> mutates the list, whereas the <code>+</code> operator returns a new list.</div>

# %% [markdown]
# ### `pop()` vs. `remove()` vs. `del()`
#
# You can <font color='red'><b>remove</b></font> item(s) from a list using three different strategies:
# - `del()`: delete element at a <font color='red'><b>specific index</b></font> `i` with `del(L[i])`
# - `pop()`: delete element at a <font color='red'><b>specific index</b></font> `i` (and return the removed element) with `L.pop(i)`. If index is not provided, `L.pop()` deletes the last element of the list by default.
# - `remove()`: remove a <font color='red'><b>specific element</b></font> `x` with `L.remove(x)`.
#   - `L.remove(x)` looks for the element `x` in `L` and, if found, removes it
#   - if `x` occurs multiple times, removes first occurrence only
#   - if `x` is not found in `L`, throws an error

# %% [markdown]
# <div class="alert alert-block alert-info"><b>NOTE</b>: <i>All</i> of the three methods <font color='red'><b>mutate</b></font> the list.</div>

# %% [markdown]
# <br>

# %%
L = [2, 1, 3, 6, 3, 7, 0]
print(f'Original L: {L}')

L.remove(2)
print(f'After L.remove(2): {L}')

L.remove(3) # removes first occurrence
print(f'After L.remove(3): {L}')

del(L[1])
print(f'After del(L[1]): {L}')

a = L.pop()
print(f'After a = L.pop(): {L}')
print(f'a = {a}')
# Out:
# Original L: [2, 1, 3, 6, 3, 7, 0]
# After L.remove(2): [1, 3, 6, 3, 7, 0]
# After L.remove(3): [1, 6, 3, 7, 0]
# After del(L[1]): [1, 3, 7, 0]
# After a = L.pop(): [1, 3, 7]
# a = 0

# %% [markdown]
# <br>
#
# <div class="alert alert-block alert-info"><b>NOTE</b>:
# <br>
# <ol>
# <li> when running <code>L.remove(3)</code>, only the first <code>3</code> is gone</li>
# <li> when using <code>L.pop()</code>, the assignment of the returned value is not mandatory</li>
# </ol>
#
# </div>

# %% [markdown]
# <br>
#
# <div class="alert alert-warning">
# <b>WARNING:</b>
# Never mutate a list as you iterate through it.
# </div>

# %% [markdown]
# **Example**: write a function that removes duplicates from a list `L1` that are present in `L2`.

# %%
def remove_dups_buggy(L1, L2):
    for item in L1:
        if item in L2:
            L1.remove(item)
    return L1

L1 = [1, 2, 3, 4]
L2 = [1, 2, 5, 6]
print(f'Result (buggy): {remove_dups_buggy(L1, L2)}')
# Out:
# Result (buggy): [2, 3, 4]

# %% [markdown]
# This is incorrect. Why?
# - Python uses an internal counter to keep track of the position in the loop
# - Mutation changes the length, but Python does not update the counter
# - The loop never visits element `2` in `L1`

# %% [markdown]
# The correct way:

# %%
def remove_dups_correct(L1, L2):
    L1copy = L1[:]
    for item in L1copy:
        if item in L2:
            L1.remove(item)
    return L1

L1 = [1, 2, 3, 4]
L2 = [1, 2, 5, 6]
print(f'Result (correct): {remove_dups_correct(L1, L2)}')
# Out:
# Result (correct): [3, 4]

# %% [markdown]
# ## Strings & Lists
#
# - Convert a string `s` to a list `L` using `L = list(s)`
#   - this yields a list where each element is a character from `s`

# %%
s = "I <3 Python"
L = list(s)
print(f'list(s): {L}')
# Out:
# list(s): ['I', ' ', '<', '3', ' ', 'P', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# - Split a string `s` on a character parameter* using `s.split()` (splits on whitespace if called with no parameters)
#   - this yields a list where each element is a portion of `s`

# %%
L_split = s.split()
print(f's.split(): {L_split}')
# Out:
# s.split(): ['I', '<3', 'Python']

# %%
L_split_custom = s.split('<')
print(f"s.split('<'): {L_split_custom}")
# Out:
# s.split('<'): ['I ', '3 Python']

# %% [markdown]
# <small>* Splits on whitespace if called with no parameters</small><br>

# %% [markdown]
# - Merge a list of characters/strings `L` using `''.join(L)`
#   - this yields a string which sees the concatenation of items in `L` with a given character** in-between (you can specify a character between quotes to add between every element)

# %%
L_join = ['Hello', 'World']
s_join = ''.join(L_join)
print(f"''.join(['Hello', 'World']): {s_join}")
# Out:
# ''.join(['Hello', 'World']): HelloWorld

# %%
s_join_custom = '_'.join(L_join)
print(f"'_'.join(['Hello', 'World']): {s_join_custom}")
# Out:
# '_'.join(['Hello', 'World']): Hello_World

# %% [markdown]
# <small>** You can specify a character (between quotes) to add between every element</small>

# %% [markdown]
# ## Other Operations
#
# Python has a set of built-in methods that you can use on lists.
#
# You can find the full list at [https://docs.python.org/3/tutorial/datastructures.html](https://docs.python.org/3/tutorial/datastructures.html)
#
# <br>
#
# <div class="alert alert-block alert-info"><b>NOTE</b>:<br> Some list methods return new values. All main list methods mutate the list in-place.</div>
#
# <br>
#
# Let's go through the most popular ones, shall we?

# %% [markdown]
# <br>
#
# - sort elements in a list: `sort()` and `sorted()`
# - flip elements last-to-first in a list: `reverse()`

# %%
L = [9, 6, 0, 3]
print(f'Original L: {L}')
# Out:
# Original L: [9, 6, 0, 3]

# %%
L1 = sorted(L) # returns sorted list in L1, does not change L
print(f'L after sorted(L): {L}')
print(f'L1: {L1}')
# Out:
# L after sorted(L): [9, 6, 0, 3]
# L1: [0, 3, 6, 9]

# %%
L.sort() # L is now mutated (sorted)
print(f'L after L.sort(): {L}')
# Out:
# L after L.sort(): [0, 3, 6, 9]

# %%
L.reverse() # L is now mutated (flipped)
print(f'L after L.reverse(): {L}')
# Out:
# L after L.reverse(): [9, 6, 3, 0]

# %% [markdown]
# ## *To mutate or not to mutate, that is the question.*
#
# - calling `sort()` mutates the list, returns nothing (`None`)
# - calling `sorted()` does not mutate the list, must assign to a new variable
#
#
# <table>
#
# <tr>
# <td align="center" style="width: 50%">
#
# `sort()` mutates:
#
# </td>
# <td align="center" style="width: 50%">
#
# `sorted()` does not mutate:
#
# </td>
# </tr>
#
# <tr>
# <td>
#
# ```python
# warm = ['red', 'yellow', 'orange']
# sortedwarm = warm.sort()
# print(f'warm: {warm}')
# print(f'sortedwarm: {sortedwarm}')
# ```
#
# </td>
# <td>
#
# ```python
# cool = ['gray', 'blue', 'green']
# sortedcool = sorted(cool)
# print(f'warm: {cool}')
# print(f'sortedwarm: {sortedcool}')
# ```
#
# </td>
# </tr>
#
# <tr>
# <td>
#
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/warm.png" >
# </div>
#
# </td>
# <td>
#
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/cool.png" >
# </div>
#
# </td>
# </tr>
#
# </table>

# %% [markdown]
# ## Aliasing
#
# **Aliasing**: if `a` refers to an object and you assign `b = a`, then both variables refer to the same object.
#
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/aliasing.png" width="250px">
# </div>

# %%
a = [1, 2, 3]
b = a
print(f'b is a: {b is a}')
# Out:
# b is a: True

# %% [markdown]
# - **Reference:** association of a variable with an object (in the example above, two references to the same object)
# - **Aliased:** an object with more than one reference has more than one name, so we say that the object is *aliased*.

# %% [markdown]
# If the aliased object is mutable (like lists), changes made to one alias affect the other:

# %%
a = [1, 2, 3]
b = a
b[0] = 42
print(f'b: {b}')
print(f'a: {a}')
# Out:
# b: [42, 2, 3]
# a: [42, 2, 3]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING:</b> This aspect can be useful, but <b>error-prone</b>!
# </div>
#
# <div class="alert alert-block alert-info">
# <b>HINT:</b> To be safe, <b>avoid aliasing</b> when working <b>with mutable objects</b>.
# </div>

# %% [markdown]
# The aliasing side-effect also holds for list methods we saw earlier:

# %%
warm = ['red', 'yellow', 'orange']
hot = warm                          # we have an alias here
hot.append('pink')
print(f'hot: {hot}')
print(f'warm: {warm}')              # breakpoint #1

warm.sort()
print(f'hot after sort: {hot}')
print(f'warm after sort: {warm}')   # breakpoint #2
# Out:
# hot: ['red', 'yellow', 'orange', 'pink']
# warm: ['red', 'yellow', 'orange', 'pink']
# hot after sort: ['orange', 'pink', 'red', 'yellow']
# warm after sort: ['orange', 'pink', 'red', 'yellow']

# %% [markdown]
# <table>
#     <tr>
#         <td>
#         <div align="center">
#         Breakpoint #1
#         <br>
#         <img src="https://introcp.github.io/src/P07/img/snap1.png" style="height: 50%;">
#         </div>
#         </td>
#         <td>
#         <div align="center">
#         Breakpoint #2
#         <br>
#         <img src="https://introcp.github.io/src/P07/img/snap2.png" style="height: 50%;">
#         </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Aliasing: Mutable vs Immutable Objects

# %% [markdown]
# Immutable data types, such as int, float, str, and tuple, are never aliased:

# %%
a = 1000
b = a                       # this is NOT an alias
b -= 1                      # this operation does not affect a
print("Original value:", a)
print("Modified value:", b)
# Out:
# Original value: 1000
# Modified value: 999

# %% [markdown]
# ## Cloning
#
# **Cloning**: create a new list (different object) by copying every element via assignment `b = a[:]`

# %%
cool = ['blue', 'green', 'grey']
chill = cool[:]  # we have a clone here
chill.append('black')
print(f'cool: {cool}')
print(f'chill: {chill}')
# Out:
# cool: ['blue', 'green', 'grey']
# chill: ['blue', 'green', 'grey', 'black']

# %% [markdown]
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/clone.png" style="height: 50%;">
# </div>

# %% [markdown]
# ## Nesting
#
# <div style="display: flex; flex-direction: row;">
#
# <div style="width: 30%;">
#
# <br>
#
# <div class="alert alert-info">
# <b>RECALL:</b>
# Lists can be heterogeneous. An element of a list can itself be a list.
# </div>
#
# <br>
# <div class="alert alert-warning">
# <b>WARNING:</b>
# Mutation and aliasing affect also nested lists.
# </div>
#
# </div>
#
# <div align="center" style="width: 10%;">
# </div>
#
# <div align="center">
# <img src="https://introcp.github.io/src/P07/img/nested.png" style="height: 330px;">
# </div>
#
# </div>

# %%
warm = ['yellow', 'orange']
hot = ['red']
brightcolors = [warm]
brightcolors.append(hot) # brightcolors: [['yellow', 'orange'], ['red']]
hot.append('pink') # hot: ['red', 'pink']

# %% [markdown]
# ## Exercise Session
#
# Check out the exercises:
# - [Strings and Lists](https://introcp.github.io/e06-python-exercises-strings-lists).
# - [Loops on Strings and Lists](https://introcp.github.io/e12-python-exercises-loops-with-strings-lists)
