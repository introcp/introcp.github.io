# %% [markdown]
# # Homework Exercises on Python (part III)
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on Python (no hints)](H03-Python-Recap-III-student.ipynb)
# - [Notebook with exercises on Python (with pseudocode)](H03-Python-Recap-III-pseudocode.ipynb)
# - [Notebook with exercises on Python (with solutions)](H03-Python-Recap-III-solution.ipynb)
