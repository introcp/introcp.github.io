# %% [markdown]
# # Exercises: Iteration
#
# ## Introduction to computer programming
#
# ### Management and Artificial Intelligence
# <br>
# <img src="https://introcp.github.io/dist/img/logo2.png" width="200px">
#
# <br><br><br>

# %% [markdown]
# ## Exercises
#
# - [Notebook with exercises on iteration (no hints)](https://introcp.github.io/e05-python-iteration-exercises-student)
# - [Notebook with exercises on iteration (with pseudocode)](https://introcp.github.io/e05-python-iteration-exercises-pseudocode)
# - [Notebook with exercises on iteration (with solutions)](https://introcp.github.io/e05-python-iteration-exercises-solution)
