# %%
s = "Hello, world"
l = list(s)

print(s)
print(l)
# Out:
# Hello, world
# ['H', 'e', 'l', 'l', 'o', ',', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
s = "The brown fox is jumping around hello"
l = s.split(" ")
l
# Out:
# ['The', 'brown', 'fox', 'is', 'jumping', 'around', 'hello']

# %%
s1 = ", ".join(l)
print(s1)
# Out:
# The, brown, fox, is, jumping, around, hello

# %%
s2 = s.replace("o", "OO")
print(s2)
# Out:
# The brOOwn fOOx is jumping arOOund hellOO

# %%
s2 = s.replace(",", ".")
print(s2)
# Out:
# The brwn fx is jumping arund hell

# %%
ln = [4, 90, 67, 58, 13, 28]
lm = [4, 90, 967, 58, 13, 28]
o = sorted(ln)

print(o, ln)
lm.sort()
print(lm, lm)
# Out:
# [4, 13, 28, 58, 67, 90] [4, 90, 67, 58, 13, 28]
# [4, 13, 28, 58, 90, 967] [4, 13, 28, 58, 90, 967]

# %%
lm = [4, 90, 967, 58, 13, 28]
lm.reverse()
print(lm)
# Out:
# [28, 13, 58, 967, 90, 4]

# %%
lm = [4, 90, 967, 58, 13, 28]
lm_r = lm[::-1]
print(lm, lm_r)
# Out:
# [4, 90, 967, 58, 13, 28] [28, 13, 58, 967, 90, 4]

# %%
l = ["kiwi", "apple", "pear", "ananas", "Pear", "Ananas", "0nanas", "!orange"]
l1 = sorted(l)
l1
# Out:
# ['kiwi', 'apple', 'pear', 'ananas', 'Pear', 'Ananas', '0nanas', '!orange']

# %%
original_list  = [1,2,3,4,5]
original_list[1] = 13
l1 = original_list
print(l1)
print(original_list)
l1[0] = 89
original_list[2] = 113
print(l1 == original_list)
print(l1, original_list)
# Out:
# [1, 13, 3, 4, 5]
# [1, 13, 3, 4, 5]
# True
# [89, 13, 113, 4, 5] [89, 13, 113, 4, 5]

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l3 = l1 + l2
print(l1, l2, l3)
# Out:
# [1, 2, 3] [4, 5, 6] [1, 2, 3, 4, 5, 6]

# %%
l1 = [1,2,3]
l1.append(4)
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
l1 = [1, 2, 3]
l2 = l1
l1[0] = 99
l2[1] = 13
l3 = l1 + l2
print(l3)
# Out:
# [99, 13, 3, 99, 13, 3]

# %%
l1 = [1, 2, 3]
l2 = l1[:]
l1[0] = 99
l2[1] = 13
l3 = l1 + l2
print(l3)
# Out:
# [99, 2, 3, 1, 13, 3]

# %%
l = [1, 2, 3, [5, [6, [7, 10]]], [8, 9]]
print(l[4])
print(l[3])
print(l[3][1])
print(l[3][1][1])
print(l[3][1][1][1])
# Out:
# [8, 9]
# [5, [6, [7, 10]]]
# [6, [7, 10]]
# [7, 10]
# 10

# %%
s = "  hello   world     "
s2 = s.strip()
print(s)
print(s2)
# Out:
#   hello   world
# hello   world
