# %%
for i in range(10):
  print(i)

# %%
for i in range(2, 13):
  print(i)

# %%
for i in range(2, 10, 2):
  print(i)

# %%
s = input("pwd: ")
while s != "password":
  s = input("pwd: ")
print("\tdone")

# %%
# for i in range(1, 10, 2):
#   print(i)

counter = 1
while counter < 10:
  print(counter)
  counter += 2 # counter = counter + 2

# %%
for i in range(100):
  if i == 9:
    break

  print(i)

# %%
counter = 1
while counter < 10:
  print(counter)
  if counter == 3:
    break
  counter += 1

# %%
counter = 1
while counter < 10:
  print(counter)

# %%
while True:
  if input() != "exit":
    print("go on")
  else:
    break

print("end")

# %%
n = int(input("up to:"))

for i in range(1, n + 1):
  print(i)

# %%
import numpy as np

for i in np.arange(1.1, 9.8, 0.7):
  print(i)

# %%
n = int(input())
sum = 0
while n > 0:
  sum += n
  n -= 1
print(sum)

# %%
n = int(input("in: "))
sum = 0
i = 1
while i <= n: # i < n+1:
  print(i)
  sum += i
  i += 1
print("sum", sum)

# %%
for i in range(2, 20, 2):
  print(i)

# %%
for i in range(20):
  if i >= 2 and i % 2 == 0:
    print(i)

# %%
n = int(input("n: "))
if n % 2 == 0:
  while n >= 1:
    print(n)
    n -= 1

# %%
for i in range(1, 11):
  print(3, "x", i, "=", 3 * i)

# %%
for i in range(1, 11):
  for j in range(1, 11):
    print(i, "x", j, "=", i * j)

# %%
while True:
  n = input("write a number or 'exit': ")
  if n == "exit":
    break

  n = float(n)
  for i in range(1, 11):
    print(n, "x", i, "=", i * n )

# %%
n = int(input("insert a number: "))
sum = 0
i = 1
while i <= n:
  if i % 2 == 0:
    sum += i
  i += 1
print(sum)

# %%
n = int(input("insert a number: "))
sum = 0
while n > 0:
  if n % 2 == 0:
    sum += n
  n -= 1
print(sum)

# %%
for i in range(5, 51, 5):
  print(i)

# %%
for i in range(1, 51):
  if i % 5 == 0:
    print(i)

# %%
i = 1
while i <= 50:
  if i % 5 == 0:
    print(i)
  i += 1
