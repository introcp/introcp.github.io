# %%
import math

number = 25
sqrt_value = math.sqrt(number)
print(f"The square root of {number} is {sqrt_value}")
# Out:
# The square root of 25 is 5.0

# %%
angle_in_radians = math.pi / 6  # 30 degrees
sine_value = math.sin(angle_in_radians)
print(f"Sine of 30 degrees (in radians) is {sine_value}")
# Out:
# Sine of 30 degrees (in radians) is 0.49999999999999994

# %%
num = 5
fact_value = math.factorial(num)
print(f"The factorial of {num} is {fact_value}")
# Out:
# The factorial of 5 is 120

# %%
number = 10
natural_log = math.log(number)
print(f"Natural logarithm of {number} is {natural_log}")
# Out:
# Natural logarithm of 10 is 2.302585092994046

# %%
base = 2
exponent = 3
power_value = math.pow(base, exponent)
print(f"{base} raised to the power of {exponent} is {power_value}")
# Out:
# 2 raised to the power of 3 is 8.0

# %%
num1 = 48
num2 = 180
gcd_value = math.gcd(num1, num2)
print(f"The GCD of {num1} and {num2} is {gcd_value}")
# Out:
# The GCD of 48 and 180 is 12

# %%
radians_value = math.pi
degrees_value = math.degrees(radians_value)
print(f"{radians_value} radians is equal to {degrees_value} degrees")
# Out:
# 3.141592653589793 radians is equal to 180.0 degrees

# %%
side_a = 3
side_b = 4
hypotenuse = math.hypot(side_a, side_b)
print(
    f"The hypotenuse of a right triangle with sides {side_a} and {side_b} is {hypotenuse}"
)
# Out:
# The hypotenuse of a right triangle with sides 3 and 4 is 5.0

# %%
num = 4.3
ceil_value = math.ceil(num)
print(f"The ceiling of {num} is {ceil_value}")
# Out:
# The ceiling of 4.3 is 5

# %%
num = 4.8
floor_value = math.floor(num)
print(f"The floor of {num} is {floor_value}")
# Out:
# The floor of 4.8 is 4

# %% [markdown]
# ## Exercises

# %% [markdown]
# Write a function that takes two sides of a right triangle and calculates the length of the hypotenuse using math.hypot().

# %%
import math


def calculate_hypotenuse(a, b):
    return math.hypot(a, b)


# Test the function
side_a = 5
side_b = 12
print(f"The hypotenuse is: {calculate_hypotenuse(side_a, side_b)}")
# Out:
# The hypotenuse is: 13.0

# %% [markdown]
# Create a function that takes an angle in degrees, converts it to radians using math.radians(), and then calculates the sine of the angle using math.sin().

# %%
import math


def sine_of_angle(degrees):
    radians = math.radians(degrees)
    return math.sin(radians)


# Test the function
angle = 45
print(f"Sine of {angle} degrees is: {sine_of_angle(angle)}")
# Out:
# Sine of 45 degrees is: 0.7071067811865476

# %% [markdown]
# - Write a function that calculates the compound interest using the formula:
#   $$  A = P \times \left(1 + \frac{r}{n}\right)^{nt}  $$
#   Where:
#   - \( A \) = the final amount after interest
#   - \( P \) = the principal amount (initial deposit)
#   - \( r \) = the annual interest rate (as a decimal)
#   - \( n \) = the number of times the interest is compounded per year
#   - \( t \) = the number of years
#
# - The function should take as input the principal amount, annual interest rate, number of times the interest is compounded per year, and the number of years. Use `math.pow()` for exponentiation.

# %%
import math


def compound_interest(principal, rate, times_compounded, years):
    amount = principal * math.pow(
        (1 + rate / times_compounded), times_compounded * years
    )
    return amount


# Test the function
P = 1000  # Principal
r = 0.05  # Annual interest rate (5%)
n = 4  # Compounded quarterly
t = 10  # Number of years

final_amount = compound_interest(P, r, n, t)
print(f"The final amount after {t} years is: {final_amount:.2f}")
# Out:
# The final amount after 10 years is: 1643.62
